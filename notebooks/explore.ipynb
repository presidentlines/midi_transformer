# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("soumikrakshit/classical-music-midi")

print("Path to dataset files:", path)
# Out:
# Downloading to /home/presi/.cache/kagglehub/datasets/soumikrakshit/classical-music-midi/1.archive...
# 100%|██████████| 2.33M/2.33M [00:00<00:00, 4.63MB/s]
# Extracting files...
# Path to dataset files: /home/presi/.cache/kagglehub/datasets/soumikrakshit/classical-music-midi/versions/1

# %%
import kagglehub

path = kagglehub.dataset_download(
    "ahemateja19bec1025/musicgenerationdataset"
)

print(path)
# Out:
# Downloading to /home/presi/.cache/kagglehub/datasets/ahemateja19bec1025/musicgenerationdataset/1.archive...
# 100%|██████████| 393k/393k [00:00<00:00, 3.11MB/s]
# Extracting files...
# /home/presi/.cache/kagglehub/datasets/ahemateja19bec1025/musicgenerationdataset/versions/1
